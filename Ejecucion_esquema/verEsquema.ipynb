# %%
import pandas as pd

# %%
#leer un csv
df = pd.read_csv('results_20241106_204728.csv')
df
# Out:
#    Iteraciones  Soluciones Iniciales  Best Accuracy  Best Loss  Best Recall  \
# 0            2                     4      63.833333   0.713949     0.638333
# 1            2                     5      54.500000   0.703053     0.545000
# 2            2                     6      61.666667   0.690535     0.616667
# 3            3                     4      50.500000   3.431443     0.505000
# 4            3                     5      66.500000   0.625282     0.665000
# 5            3                     6      58.500000   0.963573     0.585000
# 6            4                     4      69.500000   0.691302     0.695000
# 7            4                     5      60.500000   0.649667     0.605000
# 8            4                     6      60.166667   2.940122     0.601667
#
#    Best Specificity  Best F1 Score  Best AUC  Best Execution Time  \
# 0          0.533333       0.510023  0.638333             2.401887
# 1          0.650000       0.539928  0.545000             2.519260
# ...
